# %% [markdown]
# # Treeof science library

# %%
from tos.interpreters import IsiInterpreter
from tos.graph.tree_of_science import TreeOfScience

# %%
tos = TreeOfScience(IsiInterpreter(), {'data': open('sample_data/isi.txt', 'r').read()})

# %%
tos.root?

# %%
tos.root()['label']
# Out:
# ['Nicholson JK, 1999, XENOBIOTICA, V29, P1181',
#  'Viant MR, 2003, ENVIRON SCI TECHNOL, V37, P4982, DOI 10.1021/es034281x',
#  'Bundy JG, 2004, ECOTOXICOLOGY, V13, P797, DOI 10.1007/s10646-003-4477-1',
#  'Robertson DG, 2005, TOXICOL SCI, V85, P809, DOI 10.1093/toxsci/kfi102',
#  'Bundy JG, 2009, METABOLOMICS, V5, P3, DOI 10.1007/s11306-008-0152-0',
#  'Jones OAH, 2008, CHEMOSPHERE, V71, P601, DOI 10.1016/j.chemosphere.2007.08.056',
#  'Bundy JG, 2002, ENVIRON TOXICOL CHEM, V21, P1966, DOI 10.1897/1551-5028(2002)021<1966:MAOTOF>2.0.CO;2',
#  'Brown SAE, 2008, ENVIRON TOXICOL CHEM, V27, P828, DOI 10.1897/07-412.1',
#  'Bundy JG, 2007, ENVIRON SCI TECHNOL, V41, P4458, DOI 10.1021/es0700303',
#  'Westerhuis JA, 2008, METABOLOMICS, V4, P293, DOI 10.1007/s11306-008-0126-2']

# %%
tos.root(offset=0, count=20)['label']
# Out:
# ['Nicholson JK, 1999, XENOBIOTICA, V29, P1181',
#  'Viant MR, 2003, ENVIRON SCI TECHNOL, V37, P4982, DOI 10.1021/es034281x',
#  'Bundy JG, 2004, ECOTOXICOLOGY, V13, P797, DOI 10.1007/s10646-003-4477-1',
#  'Robertson DG, 2005, TOXICOL SCI, V85, P809, DOI 10.1093/toxsci/kfi102',
#  'Bundy JG, 2009, METABOLOMICS, V5, P3, DOI 10.1007/s11306-008-0152-0',
#  'Jones OAH, 2008, CHEMOSPHERE, V71, P601, DOI 10.1016/j.chemosphere.2007.08.056',
#  'Bundy JG, 2002, ENVIRON TOXICOL CHEM, V21, P1966, DOI 10.1897/1551-5028(2002)021<1966:MAOTOF>2.0.CO;2',
#  'Brown SAE, 2008, ENVIRON TOXICOL CHEM, V27, P828, DOI 10.1897/07-412.1',
#  'Bundy JG, 2007, ENVIRON SCI TECHNOL, V41, P4458, DOI 10.1021/es0700303',
#  'Westerhuis JA, 2008, METABOLOMICS, V4, P293, DOI 10.1007/s11306-008-0126-2',
#  'Waters NJ, 2005, CHEM RES TOXICOL, V18, P639, DOI 10.1021/tx049869b',
#  'Simpson MJ, 2009, ANAL BIOANAL CHEM, V394, P137, DOI 10.1007/s00216-009-2612-4',
# ...

# %%
tos.leave(offset=1, count=15)['label']
# Out:
# ['Mudiam MKR, 2013, PLOS ONE, V8, pE81077, DOI 10.1371/journal.pone.0081077',
#  'Demur C, 2013, TOXICOLOGY, V308, P74, DOI 10.1016/j.tox.2013.03.004',
#  'Wang HP, 2013, CHEM-BIOL INTERACT, V203, P588, DOI 10.1016/j.cbi.2013.03.017',
#  'Colquhoun IJ, 2007, J PESTIC SCI, V32, P200, DOI 10.1584/jpestics.R07-03',
#  'Liang YJ, 2012, INT J TOXICOL, V31, P287, DOI 10.1177/1091581812441030',
#  'Liang YJ, 2013, CHEM-BIOL INTERACT, V206, P302, DOI 10.1016/j.cbi.2013.10.002',
#  'Baylay AJ, 2012, ECOTOXICOLOGY, V21, P1436, DOI 10.1007/s10646-012-0897-0',
#  'Bamba T, 2006, J PESTIC SCI, V31, P300, DOI 10.1584/jpestics.31.300',
#  'Yang J, 2013, HUM EXP TOXICOL, V32, P196, DOI 10.1177/0960327112459533',
#  'Du LF, 2013, TOXICOL SCI, V134, P195, DOI 10.1093/toxsci/kft091',
#  'Liang YJ, 2012, BIOANALYSIS, V4, P2897, DOI 10.4155/BIO.12.277',
#  'Li MH, 2014, AQUAT TOXICOL, V146, P82, DOI 10.1016/j.aquatox.2013.10.024',
# ...

# %%
tos.trunk()['label']
# Out:
# ['Aliferis KA, 2011, METABOLOMICS, V7, P35, DOI 10.1007/s11306-010-0231-x',
#  'McKelvie JR, 2009, METABOLOMICS, V5, P84, DOI 10.1007/s11306-008-0122-6',
#  'Lin CY, 2006, J PESTIC SCI, V31, P245, DOI 10.1584/jpestics.31.245',
#  'Liang YJ, 2012, BIOMARKERS, V17, P566, DOI 10.3109/1354750X.2012.704527',
#  'Aliferis KA, 2011, PESTIC BIOCHEM PHYS, V100, P105, DOI 10.1016/j.pestbp.2011.03.004',
#  'Wang HP, 2009, CHEM RES TOXICOL, V22, P1026, DOI 10.1021/tx8004746',
#  'Viant MR, 2006, AQUAT TOXICOL, V77, P359, DOI 10.1016/j.aquatox.2006.01.009',
#  'Yuk J, 2010, ENVIRON CHEM, V7, P524, DOI 10.1071/EN10084',
#  'Wang HP, 2011, PESTIC BIOCHEM PHYS, V101, P232, DOI 10.1016/j.pestbp.2011.09.011',
#  'Kenneke JF, 2010, CHIRALITY, V22, P183, DOI 10.1002/chir.20725']

# %%
tos.trunk()['betweenness']
# Out:
# [412.6666666666667,
#  376.50000000000006,
#  280.0,
#  179.0,
#  134.0,
#  126.16666666666666,
#  71.33333333333334,
#  41.916666666666664,
#  39.66666666666667,
#  28.333333333333332]

# %%
list(zip(tos.trunk()['label'], tos.trunk()['betweenness']))
# Out:
# [('Aliferis KA, 2011, METABOLOMICS, V7, P35, DOI 10.1007/s11306-010-0231-x',
#   412.6666666666667),
#  ('McKelvie JR, 2009, METABOLOMICS, V5, P84, DOI 10.1007/s11306-008-0122-6',
#   376.50000000000006),
#  ('Lin CY, 2006, J PESTIC SCI, V31, P245, DOI 10.1584/jpestics.31.245', 280.0),
#  ('Liang YJ, 2012, BIOMARKERS, V17, P566, DOI 10.3109/1354750X.2012.704527',
#   179.0),
#  ('Aliferis KA, 2011, PESTIC BIOCHEM PHYS, V100, P105, DOI 10.1016/j.pestbp.2011.03.004',
#   134.0),
#  ('Wang HP, 2009, CHEM RES TOXICOL, V22, P1026, DOI 10.1021/tx8004746',
#   126.16666666666666),
#  ('Viant MR, 2006, AQUAT TOXICOL, V77, P359, DOI 10.1016/j.aquatox.2006.01.009',
#   71.33333333333334),
#  ('Yuk J, 2010, ENVIRON CHEM, V7, P524, DOI 10.1071/EN10084',
#   41.916666666666664),
#  ('Wang HP, 2011, PESTIC BIOCHEM PHYS, V101, P232, DOI 10.1016/j.pestbp.2011.09.011',
#   39.66666666666667),
#  ('Kenneke JF, 2010, CHIRALITY, V22, P183, DOI 10.1002/chir.20725',
#   28.333333333333332)]

# %%
tos.graph.vs['label']
# Out:
# ['Pico Y, 2008, TRAC-TREND ANAL CHEM, V27, P821, DOI 10.1016/j.trac.2008.08.009',
#  'Johnson HE, 2007, METABOLOMICS, V3, P517, DOI 10.1007/s11306-007-0065-3',
#  'Kalantzi OI, 2004, ENVIRON HEALTH PERSP, V112, P1085, DOI 10.1289/ehp.6991',
#  'Seo JS, 2013, BIODEGRADATION, V24, P795, DOI 10.1007/s10532-013-9629-2',
#  'Holmes E, 2001, CHEM RES TOXICOL, V14, P182, DOI 10.1021/tx000158x',
#  'Taylor NS, 2010, TOXICOL SCI, V118, P307, DOI 10.1093/toxsci/kfq247',
#  'Manabe M, 2006, INT J HYG ENVIR HEAL, V209, P413, DOI 10.1016/j.ijheh.2006.04.004',
#  'Bundy JG, 2009, METABOLOMICS, V5, P3, DOI 10.1007/s11306-008-0152-0',
#  'Castro-Puyana M, 2013, TRAC-TREND ANAL CHEM, V52, P74, DOI 10.1016/j.trac.2013.05.016',
#  'Aliferis KA, 2010, METABOLOMICS, V6, P96, DOI 10.1007/s11306-009-0180-4',
#  'Ibanez M, 2005, RAPID COMMUN MASS SP, V19, P169, DOI 10.1002/rcm.1764',
#  'Yuk J, 2011, ENVIRON CHEM, V8, P281, DOI 10.1071/EN11033',
# ...

# %%
isi = IsiInterpreter()
isi.parse_entry?

# %%
tos.root?
